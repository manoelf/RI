# %%
import numpy as np
import math
import pandas as pd
import nltk as nltk
import math
import operator
import ast
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/manorlf/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df = pd.read_csv("../data/estadao_noticias_eleicao.csv")
df = df.fillna('')
# Out:
#                  timestamp                                             titulo  \
# 0     2014-12-31T00:00:00Z     PT espera 30 mil pessoas em festa na Esplanada
# 1     2014-12-31T00:00:00Z             Alckmin toma posse de olho no Planalto
# 2     2014-12-31T00:00:00Z  Seis obstáculos e desafios do segundo mandato ...
# 3     2014-12-31T00:00:00Z
# 4     2014-12-31T00:00:00Z
# 5     2014-12-31T00:00:00Z
# 6     2014-12-31T00:00:00Z  Veja os desafios dos governadores que assumem ...
# 7     2014-12-31T00:00:00Z  PT impulsiona cerimônia de posse da Dilma nas ...
# 8     2014-12-31T00:00:00Z
# 9     2014-12-31T00:00:00Z  Dilma veta projeto de Suplicy que cria linha o...
# 10    2014-12-31T00:00:00Z  Dilma anuncia 14 ministros e conclui reforma m...
# 11    2014-12-31T00:00:00Z  Dilma anuncia últimos 14 ministros e fecha equipe
# 12    2014-12-31T00:00:00Z  Ex-governador critica Alckmin pela falta de ág...
# 13    2014-12-31T00:00:00Z  Veja lista completa de ministros anunciados po...
# 14    2014-12-31T00:00:00Z  'PT não pode se queixar', afirma futuro articu...
# 15    2014-12-31T00:00:00Z  Planalto confirma Juca Ferreira no Ministério ...
# 16    2014-12-31T00:00:00Z  Pimentel divulga nomes do secretariado do gove...
# 17    2014-12-31T00:00:00Z  Com recusa de Celso Amorim, Figueiredo deve fi...
# 18    2014-12-31T00:00:00Z        Ala do PT pede saída de Ideli de ministério
# 19    2014-12-31T00:00:00Z  Cid Gomes anunciará novo piso para professores...
# 20    2014-12-30T00:00:00Z  Além de ministério, PRB ganha pastas estaduais...
# 21    2014-12-30T00:00:00Z  Ministro não precisa ser expert, afirma prefei...
# 22    2014-12-30T00:00:00Z  Dilma deixa Lula e ala majoritária do PT de fo...
# 23    2014-12-30T00:00:00Z
# 24    2014-12-30T00:00:00Z  Lei de Roseana dá à ex-governadora direito a n...
# 25    2014-12-30T00:00:00Z  Alckmin chama presidente do PSDB paulista para...
# 26    2014-12-30T00:00:00Z  E-mails indicam ‘atuação direta’ de cartel no ...
# 27    2014-12-30T00:00:00Z  Menor prestígio e verba faz diplomatas buscare...
# 28    2014-12-30T00:00:00Z  'Obras de Alckmin terão significado para todo ...
# 29    2014-12-30T00:00:00Z  Cúpula da política externa proíbe uso de Faceb...
# ...                    ...                                                ...
# 8686  2014-01-05T00:00:00Z  Dados ajudam a  quebrar mitos da  política nac...
# 8687  2014-01-05T00:00:00Z  Eleição municipal e pequenas cidades induzem f...
# 8688  2014-01-05T00:00:00Z  11% dos eleitores do País são filiados a legen...
# 8689  2014-01-05T00:00:00Z   Adesão cresce em regiões de maior escolaridade
# 8690  2014-01-05T00:00:00Z  'Se sentença seguiu as regras, é difícil haver...
# 8691  2014-01-05T00:00:00Z                           Abstinência programada
# 8692  2014-01-05T00:00:00Z      Siglas descumprem cota feminina em propaganda
# 8693  2014-01-05T00:00:00Z  Bancada de mulheres no Brasil é inferior à méd...
# 8694  2014-01-05T00:00:00Z  Em prisão domiciliar, Genoino muda endereço pe...
# 8695  2014-01-05T00:00:00Z  Câmara não cumpre promessa de economia de R$ 2...
# 8696  2014-01-04T00:00:00Z  'Aliança com tucanos é a nova política', diz C...
# 8697  2014-01-04T00:00:00Z          Com base oscilante, Dilma usa menos PEC
# 8698  2014-01-04T00:00:00Z  Aos 139 anos, 'Estado' preserva defesa da libe...
# 8699  2014-01-04T00:00:00Z         Dilma aprovou menos emendas que Lula e FHC
# 8700  2014-01-04T00:00:00Z  Câmara deixa de cumprir promessa de economia d...
# 8701  2014-01-04T00:00:00Z  PSB prepara anúncio de Marina como vice de Cam...
# 8702  2014-01-04T00:00:00Z  Campos empossa novos secretários em clima de c...
# 8703  2014-01-04T00:00:00Z  Alckmin volta a dizer que espera 'investigação...
# 8704  2014-01-04T00:00:00Z  Governo atua para adiar leis sensíveis a sindi...
# 8705  2014-01-04T00:00:00Z        Calendário curto trava pauta do Congresso
# 8706  2014-01-03T00:00:00Z  Presidenciáveis privilegiam o Sudeste no cumpr...
# 8707  2014-01-03T00:00:00Z  Executivo da Siemens teve ordem para destruir ...
# 8708  2014-01-03T00:00:00Z  Governo tenta barrar projeto sobre greve de se...
# 8709  2014-01-03T00:00:00Z  Falta de acordo deve se intensificar no Congresso
# 8710  2014-01-03T00:00:00Z
# 8711  2014-01-03T00:00:00Z         Itamaraty recupera status com o Planalto
# 8712  2014-01-03T00:00:00Z        No Congresso, até ruralistas são 'verdes'
# 8713  2014-01-03T00:00:00Z             Indústria também tem lista de demandas
# 8714  2014-01-03T00:00:00Z  Ambientalistas criam pontes com oposição para ...
# 8715  2014-01-03T00:00:00Z  Ministros candidatos na eleição de outubro têm...
#
#                                               subTitulo  \
# 0     Objetivo é demonstrar apoio popular a Dilma e ...
# 1     Governador reeleito tenta amarrar tucanos paul...
# 2     Em meio a escândalo de corrupção, presidente t...
# 3     Veja as principais fotos do dia e dos eventos ...
# 4     Veja as principais fotos do dia e dos eventos ...
# 5     Veja as principais fotos do dia e dos eventos ...
# 6
# 7     Já entre os 27 governadores eleitos, apenas se...
# 8     Em setembro de 2014, após conceder entrevista ...
# 9     Proposta havia sido aprovada no Senado depois ...
# 10    Mauro Vieira vai assumir a pasta das Relações ...
# 11    Mauro Vieira vai assumir a pasta das Relações ...
# 12    Apesar das declarações, Cláudio Lembo diz que ...
# 13    Dos 14 que faltavam, 13 permanecem no cargo pa...
# 14    Novo titular da pasta responsável pela relação...
# 15    Impasse sobre Itamaraty emperra reforma minist...
# 16    Governador também anunciou a criação das pasta...
# 17    Dilma teria ficado sem alternativas para subst...
# 18    Setorial de Direitos Humanos cobra 'sinalizaçã...
# 19    Futuro Ministro da Educação se reuniu com atua...
# 20    Após conquistar posição no lugar do PC do B, s...
# 21    'Se o sujeito for bom gestor, vai muito bem',d...
# 22    Ao confirmar Pepe Vargas na pasta da articulaç...
# 23    Chefe da Casa Civil do governo Alckmin disse q...
# 24    Roseana tem pensão vitalícia de R$ 24 mil por ...
# 25    Deputado federal Duarte Nogueira irá comandar ...
# 26    Polícia Federal apreendeu em computador do núm...
# 27    Com orçamento reduzido no governo Dilma em com...
# 28    Futuro secretário destaca impacto nacional em ...
# 29    Órgão tem conduzido crise interna com alertas ...
# ...                                                 ...
# 8686
# 8687  Levantamento revela que 70% das 13,8 milhões d...
# 8688
# 8689
# 8690  Secretário-geral indica ser improvável que OEA...
# 8691
# 8692  Só em São Paulo, um em cada quatro partidos de...
# 8693  Para especialistas ouvidas pelo 'Estado', só u...
# 8694  A decisão foi comunicada na véspera ao STF; ad...
# 8695
# 8696  Governador de Pernambuco exalta ingresso do PS...
# 8697  Atual governo deve terminar com 9 emendas cons...
# 8698  Fundado em 4 de janeiro de 1875 por um grupo d...
# 8699  Atual presidente deve encerrar o mandato com 9...
# 8700  Novo sistema de registro de frequência de func...
# 8701  Após ex-ministra vetar o apoio da sigla à reel...
# 8702
# 8703  Declaração foi dada após 'Estado' revelar que ...
# 8704  Regulação de greve no   setor público e propos...
# 8705  Eleições e Copa reduzem dias de votação e difi...
# 8706  Prováveis candidatos ao Planalto viajaram mais...
# 8707  Sergio de Bona diz à PF que foi instruído a el...
# 8708
# 8709
# 8710  Às segundas e sextas-feiras, parlamentares do ...
# 8711  Figueiredo ainda tem problemas a resolver na d...
# 8712
# 8713  Assim como agronegócio, que já faz encontros c...
# 8714  Descontentes com a atuação do governo Dilma no...
# 8715  A reforma política pode ocorrer antes do fim d...
#
#                                                conteudo  \
# 0     BRASÍLIA - Após o desgaste provocado com o lan...
# 1     Reeleito em outubro, o governador tucano Geral...
# 2       1. Rearranjo das contas A nova equipe econôm...
# 3
# 4
# 5
# 6     No Acre, governador reeleito quer erradicar an...
# 7     Os perfis da presidente Dilma Rousseff, nas re...
# 8
# 9     A presidente Dilma Rousseff vetou integralment...
# 10    A presidente Dilma Rousseff concluiu nesta qua...
# 11    O Palácio do Planalto anunciou no fim da manhã...
# 12    O ex-governador e integrante da Executiva do P...
# 13    Veja a lista de ministros já anunciados pela p...
# 14    Escolhido pela presidente Dilma Rousseff para ...
# 15    (Atualizado às 6h18) BRASÍLIA - Na véspera de ...
# 16    BELO HORIZONTE - O governador eleito de Minas ...
# 17    BRASÍLIA - O ministro das Relações Exteriores,...
# 18    O setorial de Direitos Humanos do Partido dos ...
# 19    Convidado para ocupar o Ministério da Educação...
# 20    Depois de garantir que comandará o Ministério ...
# 21    Um dos principais cabos eleitorais da presiden...
# 22    BRASÍLIA - Ao anunciar ontem mais sete nomes p...
# 23
# 24    BRASÍLIA - A ex-governadora do Maranhão Rosean...
# 25    Atualizado às 21h10. Faltando apenas dois dias...
# 26    Por Ricardo Brandt, Fausto Macedo e Julia Affo...
# 27    A queda de prestígio da diplomacia no governo ...
# 28    Principal braço político do governador Geraldo...
# 29    Para tentar abafar a crise, assessores do mini...
# ...                                                 ...
# 8686  Essa mesma lógica derruba a ideia comum de que...
# 8687  A cada quatro anos, uma onda de filiações a pa...
# 8688  Há, porém, variações regionais nesse fenômeno....
# 8689  No Rio Grande do Sul, o índice de 15,8% do ele...
# 8690  Secretário-geral da Organização dos Estados Am...
# 8691  O governo começa a ter de sacrificar posições,...
# 8692  SÃO PAULO - O Brasil elegeu em 2010 uma mulher...
# 8693  SÃO PAULO - Apenas 8,9% das vagas da Câmara e ...
# 8694  Condenado em regime semiaberto no processo do ...
# 8695  No caso do cotão, como são chamados os benefíc...
# 8696  A posse de seis novos integrantes do secretari...
# 8697  A presidente Dilma Rousseff adotou como estrat...
# 8698  São 139 anos de fundação e 134 anos de vida in...
# 8699  A presidente Dilma Rousseff adotou como estrat...
# 8700  Brasília - A promessa do presidente da Câmara,...
# 8701  O PSB espera que Marina Silva anuncie publicam...
# 8702  Murilo Guerra, ex-superintendente do Sebrae em...
# 8703  SÃO PAULO - O governador de São Paulo, Geraldo...
# 8704  Além dos impasses político-eleitorais da base ...
# 8705  O tensionamento eleitoral que impediu que proj...
# 8706  A região Sudeste foi o principal destino das v...
# 8707  O gerente-geral da área de projetos corporativ...
# 8708  O caso mais evidente foi no debate sobre a reg...
# 8709  Casos exemplares são os projetos que mexem com...
# 8710
# 8711  Em agosto, quando assumiu o Ministério das Rel...
# 8712  Alguém definiria como verdes os senadores Fern...
# 8713  Em um esforço para pautar o debate político da...
# 8714  Aliados incondicionais da ex-ministra Marina S...
# 8715  SÃO PAULO - A presidente Dilma Rousseff não de...
#
#                                                     url  idNoticia
# 0     http://politica.estadao.com.br/noticias/geral,...          1
# 1     http://politica.estadao.com.br/noticias/geral,...          2
# 2     http://politica.estadao.com.br/noticias/geral,...          3
# 3     http://fotos.estadao.com.br/fotos/politica,dil...          4
# 4     http://fotos.estadao.com.br/fotos/politica,dil...          5
# 5     http://fotos.estadao.com.br/fotos/politica,dil...          6
# 6     http://politica.estadao.com.br/noticias/geral,...          7
# 7     http://politica.estadao.com.br/noticias/geral,...          8
# 8     http://tv.estadao.com.br/videos,politica,dilma...          9
# 9     http://politica.estadao.com.br/noticias/geral,...         10
# 10    http://politica.estadao.com.br/noticias/geral,...         11
# 11    http://politica.estadao.com.br/noticias/geral,...         12
# 12    http://politica.estadao.com.br/blogs/julia-dua...         13
# 13    http://politica.estadao.com.br/noticias/geral,...         14
# 14    http://politica.estadao.com.br/noticias/geral,...         15
# 15    http://politica.estadao.com.br/noticias/geral,...         16
# 16    http://politica.estadao.com.br/noticias/geral,...         17
# 17    http://politica.estadao.com.br/noticias/geral,...         18
# 18    http://politica.estadao.com.br/noticias/geral,...         19
# 19    http://politica.estadao.com.br/noticias/geral,...         20
# 20    http://politica.estadao.com.br/noticias/geral,...         21
# 21    http://politica.estadao.com.br/noticias/geral,...         22
# 22    http://politica.estadao.com.br/noticias/geral,...         23
# 23    http://tv.estadao.com.br/videos,politica,para-...         24
# 24    http://politica.estadao.com.br/noticias/geral,...         25
# 25    http://politica.estadao.com.br/noticias/geral,...         26
# 26    http://politica.estadao.com.br/blogs/fausto-ma...         27
# 27    http://politica.estadao.com.br/noticias/geral,...         28
# 28    http://politica.estadao.com.br/noticias/geral,...         29
# 29    http://politica.estadao.com.br/noticias/geral,...         30
# ...                                                 ...        ...
# 8686  http://politica.estadao.com.br/noticias/eleico...       8687
# 8687  http://politica.estadao.com.br/noticias/eleico...       8688
# 8688  http://politica.estadao.com.br/noticias/eleico...       8689
# 8689  http://politica.estadao.com.br/noticias/eleico...       8690
# 8690  http://politica.estadao.com.br/noticias/eleico...       8691
# 8691  http://politica.estadao.com.br/noticias/eleico...       8692
# 8692  http://politica.estadao.com.br/noticias/geral,...       8693
# 8693  http://politica.estadao.com.br/noticias/geral,...       8694
# 8694  http://politica.estadao.com.br/noticias/geral,...       8695
# 8695  http://politica.estadao.com.br/noticias/geral,...       8696
# 8696  http://politica.estadao.com.br/noticias/eleico...       8697
# 8697  http://politica.estadao.com.br/noticias/eleico...       8698
# 8698  http://politica.estadao.com.br/noticias/geral,...       8699
# 8699  http://politica.estadao.com.br/noticias/geral,...       8700
# 8700  http://politica.estadao.com.br/noticias/geral,...       8701
# 8701  http://politica.estadao.com.br/noticias/geral,...       8702
# 8702  http://politica.estadao.com.br/noticias/geral,...       8703
# 8703  http://politica.estadao.com.br/noticias/geral,...       8704
# 8704  http://politica.estadao.com.br/noticias/eleico...       8705
# 8705  http://politica.estadao.com.br/noticias/eleico...       8706
# 8706  http://politica.estadao.com.br/noticias/eleico...       8707
# 8707  http://politica.estadao.com.br/noticias/eleico...       8708
# 8708  http://politica.estadao.com.br/noticias/geral,...       8709
# 8709  http://politica.estadao.com.br/noticias/geral,...       8710
# 8710  http://tv.estadao.com.br/videos,politica,os-re...       8711
# 8711  http://politica.estadao.com.br/noticias/eleico...       8712
# 8712  http://politica.estadao.com.br/noticias/eleico...       8713
# 8713  http://politica.estadao.com.br/noticias/eleico...       8714
# 8714  http://politica.estadao.com.br/noticias/eleico...       8715
# 8715  http://politica.estadao.com.br/noticias/geral,...       8716
#
# [8716 rows x 6 columns]

# %%
# Feedback

feed_back = pd.read_csv('gabarito.csv')
feed_back
# Out:
#             str_busca                          google  \
# 0       segundo turno  [1062, 1942, 2161, 2078, 2073]
# 1           lava jato     [616, 164, 1734, 163, 6716]
# 2      projeto de lei    [2853, 275, 978, 7092, 3171]
# 3      compra de voto    [2200, 8615, 2265, 7746, 82]
# 4  ministério público     [64, 6652, 164, 6550, 8615]
#
#                     busca_binaria                              tf  \
# 0     [2048, 1, 2049, 2050, 4096]     [2744, 7, 2112, 7672, 2388]
# 1           [3, 13, 15, 27, 6177]      [163, 353, 2807, 127, 359]
# 2  [3584, 6145, 8194, 8706, 6660]     [7, 3942, 7017, 1250, 6942]
# 3  [7424, 2178, 6531, 5122, 2311]   [3942, 7017, 5129, 2047, 748]
# 4     [8194, 7, 4104, 8201, 4109]  [6798, 8018, 6244, 6965, 6550]
#
#                             tfidf                            bm25
# 0  [2744, 2112, 7672, 1235, 2388]  [2744, 2112, 7672, 2388, 2178]
# 1      [163, 353, 2807, 127, 359]      [163, 353, 2807, 127, 359]
# 2  [2232, 6461, 2853, 3171, 3942]  [2232, 6461, 3171, 2853, 3170]
# 3  [7343, 7293, 6791, 3942, 2047]  [7343, 7293, 6791, 7329, 8615]
# 4  [6798, 8018, 6244, 6965, 6550]  [6798, 8018, 6244, 6965, 6550]

# %% [markdown]
# <h1>Vector Space Retrieval Model</h1>

# %%
INVERTED_INDEX = dict()

# %%
def search_term(term, data):
    '''
    Search term presence in data frame and calculate its term frequence. Also full fill the dictionary 
    with the result for future new searchs.
            
    ARGS:
        term: String with single word, that word is the term to be seach in the data frame.
        data: Data frame, where the terms will be search.
        
    RETURN:
        tuple (int n, list l): where n is the total of documents witch the term is presente at least once
                               l is a list of tuple (doc, tf), where doc is the notice id and tf is its 
                               term frequence.
    '''
    
    result = []
    cont = 0
    
    if (term in INVERTED_INDEX):
        result = INVERTED_INDEX[term]
    else:
        
        rows = data.shape[0]
                
        for doc in range(rows):
            title = (data.loc[doc, 'titulo']).lower()
            sub_title = (data.loc[doc, 'subTitulo']).lower()
            content = (data.loc[doc, 'conteudo']).lower()
                        
            tf = 0
            text = nltk.word_tokenize(title + ' ' + sub_title + ' ' + content)
            i = 0
            
            while (i < len(text)):
                if (text[i].lower() == term):
                    tf += 1
                    exist = True
                i += 1
            if (tf):
                id_notice = data.loc[doc, 'idNoticia']
                result.append((id_notice, tf))
                cont += 1
        INVERTED_INDEX[term] = (cont, result)
    
    return INVERTED_INDEX[term]

# %%
def intersection(query, data): 
    '''
    To get a dictionary with all notice id and its terms frequency in a list representing for all terms
    of the query.
        
    ARGS:
        query: String with the with words or terms to be seach
        data: Data frame, where the terms will be search.
        
    RETURN:
        {doc:l} doc is the notice id and l is a list with the tf (term frequency) of each term in the query
        
    '''
    q = query.split()
    dic_docs = dict()
    
    for term in q:
        term_set = search_term(term, data)
        for doc in term_set[1]:
            if (doc[0] in dic_docs):
                dic_docs[doc[0]].append(doc[1])
            else:
                dic_docs[doc[0]] = [doc[1]]
    return dic_docs

# %% [markdown]
# <h1>VSM Binary</h1>

# %%
def vsm_binary(query, data):
    '''
    Virtual Space Model: Binary
        Search for a specific query in a data frame with binary logic. 
        But here we use a intersection, all notice id needs to be in all docs simultaneously
        
    ARGS:
        query: String with the with words or terms to be seach
        data: Data frame, where the terms will be search.
        
    RETURN:
        List of tuple (doc, tf), where doc repersents the notice id and tf its term frequency
    
    '''
    q = query.split()
    dic_docs = intersection(query,data)
   
    result = []
    
    for doc in dic_docs.keys():
        if (len(dic_docs[doc]) == len(q)):
            result.append((doc, len(q)))
            
    return result

# %% [markdown]
# <h1>VSM TF</h1>

# %%
def vsm_tf(query, data):
    '''
    Improved VSM with Term Frequency Weighting
        Search for a specific query in a data frame with TF logic. For each term in the query it will result,,
        a notice id with the sum of tf for each doc witch it's is present the term.
        But here we use a intersection, all notice id needs to be in all docs simultaneously.
        
    ARGS:
        query: String with the with words or terms to be seach
        data: Data frame, where the terms will be search.
        
    RETURN:
        List of tuple (doc, tf), where doc repersents the notice id and tf its term frequency
    
    '''
    q = query.split()
    dic_docs = intersection(query,data)
    
    result = []
    
    for doc in dic_docs.keys():
        if (len(dic_docs[doc]) == len(q)):
            result.append((doc, sum(dic_docs[doc])))
            
    return result

# %% [markdown]
# <h1>VSM TF-IDF</h1>

# %%
def vsm_tf_idf(query, data):
    '''
    Improvement of Vector Placement: Adding Inverse Document Frequency (IDF)
    IDF(W) = log[(M+1)/k]
        W: Word
        M: Total of Numbers in colection
        K: Total of documents containing  W (Doc Frequency )
        
    Trying to improve search using TF-IDF. For each term it will calculate IDF and multiply for tf, and then sum
    in order to improve Weighting.
    Here we use a intersection, all docs selected needs to have the term at least once.
        
    ARGS:
        query: String with the with words or terms to be seach.
        data: Data frame, where the terms will be search.
        
    RETURN:
        List of tuple (doc, tf), where doc repersents the notice id and tf-idf calc.
    
    '''
    q = query.split()
    dic_docs = intersection(query, data)
    
    
    result = []
    
    for doc in dic_docs.keys():
        tf_idf_sum = 0
        if (len(dic_docs[doc]) == len(q)):
            for i in range(len(q)):
                tf_idf_sum += dic_docs[doc][i] * idf(q[i], data)
            result.append((doc, tf_idf_sum))
            
    return result





def idf(term, data):
    '''
    Calculates IDF of a Word.
        IDF(W) = log[(M+1)/k]
            W: Word
            M: Total of Numbers in colection
            K: Total of documents containing  W (Doc Frequency )
    ARGS:
        term: Term or word to be calculated the idf.
        data: Data frame.
    
    RETURN:
        IDF for term.
    '''
    size = search_term(term, data)[0]
    total_docs = data.shape[0]
    calc = math.log((total_docs - 1)/ size)
    
    return calc

# %% [markdown]
# <h1>BM25</h1>

# %%
def vsm_bm25(query, data):
    '''
    BM25 Transformation 
        – has an upper bound
        – is robust and effective 
     
    ARGS:
        query: String with the with words or terms to be seach.
        data: Data frame, where the terms will be search.
    
    RETURN:
         List of tuple (doc, tf), where doc repersents the notice id and its BM25.
    '''
    q = query.split()
    dic_docs = intersection(query, data)
    
    result = []
    
    for doc in dic_docs.keys():
        bm25_sum = 0
        if (len(dic_docs[doc]) == len(q)):
            for i in range(len(q)):
                bm25_sum += bm25(dic_docs[doc][i])
            result.append((doc, bm25_sum))
            
    return result
    
    
def bm25(tf):
    '''
    Calculates the BM25 for a specific tf
    
    '''
    k = 5
    calc = ((k + 1) * tf)/(tf + k)
    return calc

# %% [markdown]
# <h1>Mean Average Precision (MAP)</h1>

# %%
def apk(actual, predicted, k=10):
    """
    Computes the average precision at k.
    This function computes the average prescision at k between two lists of
    items.
    Parameters
    ----------
    actual : list
             A list of elements that are to be predicted (order doesn't matter)
    predicted : list
                A list of predicted elements (order does matter)
    k : int, optional
        The maximum number of predicted elements
    Returns
    -------
    score : double
            The average precision at k over the input lists
    """
    if len(predicted)>k:
        predicted = predicted[:k]

    score = 0.0
    num_hits = 0.0

    for i,p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i+1.0)

    if not actual:
        return 0.0

    return score / min(len(actual), k)

def mapk(actual, predicted, k=10):
    """
    Computes the mean average precision at k.
    This function computes the mean average prescision at k between two lists
    of lists of items.
    Parameters
    ----------
    actual : list
             A list of lists of elements that are to be predicted 
             (order doesn't matter in the lists)
    predicted : list
                A list of lists of predicted elements
                (order matters in the lists)result
    k : int, optional
        The maximum number of predicted elements
    Returns
    -------
    score : double
            The mean average precision at k over the input lists
    """
    return np.mean([apk(a,p,k) for a,p in zip(actual, predicted)])

# %%
def top_five(query, model, data):
    '''
    Given a specific model it will make a search for the docs witch the terms are presents.
    
    ARGS:
        query: String with the with words or terms to be seach.
        model: Specif model for the search, should be binay, tf, tf-idf or bm25
        data: Data frame, where the terms will be search. 
        
    RETURN:
        Top 5 documents for the search.
        
    '''
    result = []
    answer = []
    if (model == 'binary'):
        result = vsm_binary(query, data)
    elif (model == 'tf'):
        result = vsm_tf(query, data)
    elif (model == 'tf-idf'):
        result = vsm_tf_idf(query, data)
    else:
        result = vsm_bm25(query, data)
    
    result.sort(key=operator.itemgetter(1), reverse=True)
    
    for i in range(5):
        answer.append(result[i][0])

    
    return answer

# %% [markdown]
# <h2>For testing propose only</h2>

# %%
def get_google_result(feedback):
    result = []
    for doc in feedback.google:
        result.append(ast.literal_eval(doc))
    return result

def get_seach_result(feedback, model):
    '''
    Get a result from the feedback in order to compare with the implemented algorithm.
    
    ARGS:
        feedback: Feedback to compare with algoritm results.
        model: Model to get specific result.
    RESULT:
        Feedback for the given model.
    '''
    
    source = []
    result = []
    if (model == 'binary'):
        source = feedback.busca_binaria
    elif (model == 'tf'):
        source = feedback.tf
    elif (model == 'tf-idf'):
        source = feedback.tfidf
    else:
        source = feedback.bm25
    
    for i in range(len(source)):
        result.append(ast.literal_eval(source[i]))
    return result

def get_str_search(feedback, model, data):
    result = []
    for i in range(5):
        result.append(top_five(feedback.str_busca[i], model, data))
    return result

# %% [markdown]
# <h1>VSM BINARY PRECISION</h1>

# %%
result = get_str_search(feed_back, 'binary', df)
answer = get_seach_result(feed_back, 'binary')
google = get_google_result(feed_back)
   
print('Binary Precision: %.3f' % (mapk(answer, result, k=5)))
print('Precision Google: %.3f' % (mapk(google, result, k=5)))
# Out:
# Binary Precision: 0.240
# Precision Google: 0.040

# %% [markdown]
# <h1>VSM TF PRECISION</h1>

# %%
tf_result = get_str_search(feed_back, 'tf', df)
answer = get_seach_result(feed_back, 'tf')
google = get_google_result(feed_back)

print('TF Precision: %.3f' % (mapk(answer, tf_result, k=5)))
print('Precision Google: %.3f' % (mapk(google, tf_result, k=5)))
# Out:
# TF Precision: 1.000
# Precision Google: 0.048

# %% [markdown]
# <h1>VSM TF-IDF PRECISION</h1>

# %%
tf_idf_result = get_str_search(feed_back, 'tf-idf', df)
answer = get_seach_result(feed_back, 'tf-idf')
google = get_google_result(feed_back)

print('TF-IDF Precision: %.3f' % (mapk(answer, tf_idf_result, k=5)))
print('Precision Google: %.3f' % (mapk(google, tf_idf_result, k=5)))
# Out:
# TF-IDF Precision: 0.761
# Precision Google: 0.084

# %% [markdown]
# <h1>VSM BM25 PRECISION</h1>

# %%
bm25_result = get_str_search(feed_back, 'bm25', df)
answer = get_seach_result(feed_back, 'bm25')
google = get_google_result(feed_back)

print('BM25 Precision: %.3f' % (mapk(answer, bm25_result, k=5)))
print('Precision Google: %.3f' % (mapk(google, bm25_result, k=5)))
# Out:
# BM25 Precision: 0.737
# Precision Google: 0.118

# %% [markdown]
# <h1>Avaliation</h1>
#
# <p>
#
# For all result, the best output was by VSM TF witch gave a precision of 1.0, but the google precision was not that good with 0.048.
#
# The best google precision was by VSM BM25 with 0.118, also showed a resonable result with 0.737.
#
# </p>
